# %% [markdown]
# # Data Analysis Of Employees In ABC Company

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
emplys=pd.read_csv("C:\\Users\\USER\\Downloads\\myexcel - myexcel.csv.csv")
emplys
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# chage entire column heiht

import random
hg=[]
for i in range(0,458):
    c=random.randint(150,180)
    hg.append(c)
hg
df1=pd.DataFrame(hg)
df1
emplys=pd.read_csv("C:\\Users\\USER\\Downloads\\myexcel - myexcel.csv.csv")
emplys['Height']=hg
emplys
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     162     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     153     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     178     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     178     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     158     203
# 454      Raul Neto       Utah Jazz      25       PG   24     174     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     170     256
# 456    Jeff Withey       Utah Jazz      24        C   26     155     231
# 457       Priyanka       Utah Jazz      34        C   25     169     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#how many members in each team

team_splt=emplys['Team'].value_counts()

#persentage splitting with respect to total employees
t=emplys.Team
prsntg_tm=t.value_counts(normalize=True).mul(100).round(1).astype(str)+'%'

#shows in a dataframe
out=pd.DataFrame({"TEAM":team_splt.index,"COUNT":team_splt.values,"PERCENTAGE":prsntg_tm.values})
print(out)
# Out:
#                       TEAM  COUNT PERCENTAGE
# 0     New Orleans Pelicans     19       4.1%
# 1        Memphis Grizzlies     18       3.9%
# 2                Utah Jazz     16       3.5%
# 3          New York Knicks     16       3.5%
# 4          Milwaukee Bucks     16       3.5%
# 5            Brooklyn Nets     15       3.3%
# 6   Portland Trail Blazers     15       3.3%
# 7    Oklahoma City Thunder     15       3.3%
# 8           Denver Nuggets     15       3.3%
# 9       Washington Wizards     15       3.3%
# 10              Miami Heat     15       3.3%
# 11       Charlotte Hornets     15       3.3%
# 12           Atlanta Hawks     15       3.3%
# 13       San Antonio Spurs     15       3.3%
# 14         Houston Rockets     15       3.3%
# 15          Boston Celtics     15       3.3%
# 16          Indiana Pacers     15       3.3%
# 17         Detroit Pistons     15       3.3%
# 18     Cleveland Cavaliers     15       3.3%
# 19           Chicago Bulls     15       3.3%
# ...

# %% [markdown]
# ### Visualize the report

# %%
out.plot(x="TEAM",y="COUNT",kind="bar",color="m")

plt.title("Team V/S Employees in each team")
plt.xlabel("TEAM")
plt.ylabel("COUNT")
plt.show()

# %% [markdown]
# # segregate employees with respect to position

# %%
#different positions in the data

emplys['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#employees data with position SG

po_stn=emplys.loc[emplys['Position']=='SG']
print(po_stn)
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 2        John Holland          Boston Celtics      30       SG   27     161
# 3         R.J. Hunter          Boston Celtics      28       SG   22     177
# 12        Evan Turner          Boston Celtics      11       SG   27     151
# 13        James Young          Boston Celtics      13       SG   20     177
# 15   Bojan Bogdanovic           Brooklyn Nets      44       SG   27     175
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28     151
# 437     C.J. McCollum  Portland Trail Blazers       3       SG   24     158
# 438      Luis Montero  Portland Trail Blazers      44       SG   23     151
# 444        Alec Burks               Utah Jazz      10       SG   24     166
# 449       Rodney Hood               Utah Jazz       5       SG   23     164
#
#      Weight            College     Salary
# ...

# %%
#employees data with position PF

pstn2=emplys.loc[emplys['Position']=='PF']
print(pstn2)
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 4       Jonas Jerebko          Boston Celtics       8       PF   29     152
# 5        Amir Johnson          Boston Celtics      90       PF   29     177
# 6       Jordan Mickey          Boston Celtics      55       PF   21     152
# 24   Chris McCullough           Brooklyn Nets       1       PF   21     153
# 25        Willie Reed           Brooklyn Nets      33       PF   26     169
# ..                ...                     ...     ...      ...  ...     ...
# 435    Meyers Leonard  Portland Trail Blazers      11       PF   24     156
# 441       Noah Vonleh  Portland Trail Blazers      21       PF   20     176
# 442     Trevor Booker               Utah Jazz      33       PF   28     172
# 446    Derrick Favors               Utah Jazz      15       PF   24     159
# 452        Trey Lyles               Utah Jazz      41       PF   20     170
#
#      Weight       College      Salary
# ...

# %%
#employees data with position SF

pstn4=emplys.loc[emplys['Position']=='SF']
print(pstn4)
# Out:
#                        Name                    Team  Number Position  Age  \
# 1               Jae Crowder          Boston Celtics      99       SF   25
# 32   Thanasis Antetokounmpo         New York Knicks      43       SF   23
# 33          Carmelo Anthony         New York Knicks       7       SF   32
# 35         Cleanthony Early         New York Knicks      11       SF   25
# 42             Lance Thomas         New York Knicks      42       SF   28
# ..                      ...                     ...     ...      ...  ...
# 428         Al-Farouq Aminu  Portland Trail Blazers       8       SF   25
# 432        Maurice Harkless  Portland Trail Blazers       4       SF   23
# 448          Gordon Hayward               Utah Jazz      20       SF   26
# 450              Joe Ingles               Utah Jazz       2       SF   28
# 451           Chris Johnson               Utah Jazz      23       SF   26
#
#      Height  Weight        College      Salary
# ...

# %%
#employees data with position C

pstn5=emplys.loc[emplys['Position']=='C']
print(pstn5)
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     163
# 10   Jared Sullinger          Boston Celtics       7        C   24     166
# 14      Tyler Zeller          Boston Celtics      44        C   26     167
# 23       Brook Lopez           Brooklyn Nets      11        C   28     154
# 27        Henry Sims           Brooklyn Nets      14        C   26     163
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     152
# 447      Rudy Gobert               Utah Jazz      27        C   23     172
# 455     Tibor Pleiss               Utah Jazz      21        C   26     179
# 456      Jeff Withey               Utah Jazz      24        C   26     157
# 457         Priyanka               Utah Jazz      34        C   25     150
#
#      Weight         College      Salary
# ...

# %% [markdown]
# ### which age group most employees belongs

# %%
plt.hist(emplys["Age"],bins=10,color='m')
plt.xlabel("age group")
plt.ylabel("employees")
plt.title("AGE DISTRIBUTION OF EMPLOYEES")
plt.show()

# %% [markdown]
# ### under which team and position spending in term of salary high

# %%
grp=emplys.groupby(["Team","Position"])["Salary"].sum().reset_index()
high=grp[grp["Salary"]==grp["Salary"].max()]
print("the team and position in term of salary are : ",high)
# Out:
# the team and position in term of salary are :                    Team Position      Salary
# 67  Los Angeles Lakers       SF  31866445.0

# %%
#correlation between age and salary

emplys['Salary']=emplys['Salary'].fillna(0)
emplys['Salary']=emplys['Salary'].astype(int)
emplys['Age'].corr(emplys['Salary'])
plt.title("correlation between age and salary")
sns.scatterplot(x="Age",y="Salary",data=emplys,color="m")
# Out:
# <Axes: title={'center': 'correlation between age and salary'}, xlabel='Age', ylabel='Salary'>
